# %% [markdown]
# # Tüdőrák predikciója vizelet LC–MS metabolomikai profilból
#
# *feature selection és gépi tanulási modellek összehasonlítása*
#
# *Ambrus Csaba*

# %% [markdown]
# ## 0. Setup

# %%
BRANCH = "cursor/metabolomics-ml-benchmark-tf-mlp"

from google.colab import drive
drive.mount('/content/drive')

# %cd /content
import os
if not os.path.exists("/content/MetabolKD/.git"):
    # !git clone --branch {BRANCH} --single-branch https://github.com/csambrus/MetabolKD.git
else:
    # %cd /content/MetabolKD
    # !git fetch origin {BRANCH}
    # !git checkout {BRANCH}
    # !git pull origin {BRANCH}

# %cd /content/MetabolKD
# %pip install -r ./requirements.txt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# /content/MetabolKD
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 4), reused 6 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 1.22 MiB | 11.11 MiB/s, done.
# From https://github.com/csambrus/MetabolKD
#  * branch            cursor/metabolomics-ml-benchmark-tf-mlp -> FETCH_HEAD
#    76872c3..2d930fb  cursor/metabolomics-ml-benchmark-tf-mlp -> origin/cursor/metabolomics-ml-benchmark-tf-mlp
# Already on 'cursor/metabolomics-ml-benchmark-tf-mlp'
# Your branch is behind 'origin/cursor/metabolomics-ml-benchmark-tf-mlp' by 1 commit, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
# From https://github.com/csambrus/MetabolKD
#  * branch            cursor/metabolomics-ml-benchmark-tf-mlp -> FETCH_HEAD
# Updating 76872c3..2d930fb
# Fast-forward
#  notebooks/mtbls28_20260512d.ipynb | 1608 ++++++++++++++++++++++++++++++++++++-
#  src/metabolomics_ml.py            |  138 +++-
#  2 files changed, 1685 insertions(+), 61 deletions(-)
# /content/MetabolKD
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 3)) (2.10.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 8)) (0.14.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 10)) (4.13.0.92)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 11)) (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 12)) (4.67.3)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 13)) (7.7.1)
# Requirement already satisfied: jupyterlab_widgets in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 14)) (3.0.16)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 15)) (3.2.0)
# Requirement already satisfied: tensorflow[and-cuda] in /usr/local/lib/python3.12/dist-packages (from -r ./requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (26.1)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: nvidia-cublas-cu12<13.0,>=12.5.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.3.0.75 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cufft-cu12<12.0,>=11.2.3.61 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12<11.0,>=10.3.6.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12<12.0,>=11.6.3.83 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12<13.0,>=12.5.1.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-nccl-cu12<3.0,>=2.25.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras->-r ./requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras->-r ./requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras->-r ./requirements.txt (line 2)) (0.19.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (3.29.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (12.9.4)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r ./requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r ./requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r ./requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r ./requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r ./requirements.txt (line 5)) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r ./requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r ./requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->-r ./requirements.txt (line 8)) (1.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r ./requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r ./requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r ./requirements.txt (line 9)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r ./requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r ./requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->-r ./requirements.txt (line 13)) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->-r ./requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->-r ./requirements.txt (line 13)) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->-r ./requirements.txt (line 13)) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->-r ./requirements.txt (line 13)) (7.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (0.47.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (6.5.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (4.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r ./requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]->-r ./requirements.txt (line 1)) (3.1.8)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (6.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r ./requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->-r ./requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (5.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras->-r ./requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (7.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.25.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 13)) (4.9.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (2.8.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (4.13.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r ./requirements.txt (line 13)) (1.4.0)

# %%
import sys
from pathlib import Path

PROJECT_ROOT = "content/MetabolKD"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)

from src.config import OUTPUT_DIR, FIGURES_DIR, REPORTS_DIR, GDRIVE_OUTPUT
from src.runtime_setup import setup_tensorflow_runtime, setup_notebook_error_logger, set_global_seed

set_global_seed()
setup_notebook_error_logger()
setup_tensorflow_runtime()

for d in [Path(OUTPUT_DIR), Path(FIGURES_DIR), Path(REPORTS_DIR)]:
    d.mkdir(parents=True, exist_ok=True)

print("FIGURES_DIR:", FIGURES_DIR)
print("REPORTS_DIR:", REPORTS_DIR)
# Out:
# PROJECT_ROOT: content/MetabolKD
# Globalis seed beallitva: 42
# ✅ Globális hiba-logger aktív.
# TF version: 2.20.0
# GPUs:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# CPU cores:  12
# CUDA_VISIBLE_DEVICES = None
# TF version = 2.20.0
# Built with CUDA = True
# GPUs = [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Logical GPUs = [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU matmul done in 0.15343594551086426 sec
# 12

# %% [markdown]
# ## 1. Adatbetöltés

# %%
from src.download_dataset import download_dataset, combine_pos_neg_to_feature_matrix

data = download_dataset()
X, meta = combine_pos_neg_to_feature_matrix(data)

# ML célváltozó
target_col = "class_label"  # Lung cancer vs Control

# Csak címkézett minták
mask = meta[target_col].notna()
X = X.loc[mask].copy()
meta = meta.loc[mask].copy()

# Biztonság: indexek egyezzenek
meta = meta.reindex(X.index)

X_raw = X
y = meta[target_col]

print("X_raw:", X_raw.shape)
print(y.value_counts(dropna=False))
# Out:
# DATA_DIR: megvan /content/MetabolKD/data/MTBLS28
# MTBLS28 raw:
#   sample:    (2010, 27)
#   assay_pos: (1005, 35)
#   assay_neg: (1005, 35)
#   maf_pos:   (1807, 1026)
#   maf_neg:   (1359, 1026)
# POS feature matrix: (1005, 1807)
# NEG feature matrix: (1005, 1359)
# Combined feature matrix: (1005, 3166)
# Csoportok:
# class_label
# Control        536
# Lung cancer    469
# Name: count, dtype: int64
# X_raw: (1005, 3166)
# class_label
# Control        536
# Lung cancer    469
# Name: count, dtype: int64

# %% [markdown]
# ## 2. QC és preprocessing

# %%
from src.metabolomics_qc import qc_sample_table
from src.metabolomics_plotting import plot_qc_bars

qc = qc_sample_table(X_raw)
print(qc.describe())
fig = plot_qc_bars(qc, meta, hue_col="class_label")
fig.savefig(Path(FIGURES_DIR) / "qc_overview_mtbls28.png", dpi=150, bbox_inches="tight")
# Out:
#        total_signal  n_missing  missing_frac
# count  1.005000e+03     1005.0        1005.0
# mean   7.478392e+06        0.0           0.0
# std    4.417414e+05        0.0           0.0
# min    5.207632e+06        0.0           0.0
# 25%    7.231368e+06        0.0           0.0
# 50%    7.506417e+06        0.0           0.0
# 75%    7.774351e+06        0.0           0.0
# max    8.636358e+06        0.0           0.0

# %% [markdown]
# ### Preprocessing

# %%
from src.metabolomics_preprocessing import nmr_style_matrices, preprocess_feature_matrix

blocks = nmr_style_matrices(X_raw, impute_first=True)
for k, df in blocks.items():
    print(k, df.shape)
X_pareto = blocks["X_pareto"]
X_log = blocks["X_log"]

X_proc, steps = preprocess_feature_matrix(X_raw)
print("Klasszikus LC–MS lépések:", " → ".join(steps))
X_proc.head()
# Out:
# X_raw (1005, 3166)
# X_pqn (1005, 3166)
# X_log (1005, 3166)
# X_pareto (1005, 3166)
# Klasszikus LC–MS lépések: median_sample_norm → impute_half_min → log1p → pareto_columns
#            pos__mz=61.04058; rt=23.70  pos__mz=65.03961; rt=194.32  \
# sample_id
# 000801                      -0.248868                    -0.360994
# 000901                       0.752984                    -0.329093
# 001001                       0.777603                     2.197781
# 001101                      -0.904921                    -0.360162
# 001201                       0.890104                    -0.282187
#
#            pos__mz=67.05510; rt=129.65  pos__mz=69.03440; rt=134.59  \
# sample_id
# 000801                        0.193660                     0.098805
# 000901                        0.051732                     0.071984
# 001001                        0.208522                     0.425780
# 001101                        0.134744                     1.067981
# 001201                       -0.101449                     0.074048
#
#            pos__mz=69.07064; rt=168.14  pos__mz=69.07063; rt=46.95  \
# sample_id
# 000801                       -0.379142                    1.147101
# 000901                        0.168638                   -0.294499
# 001001                        0.387521                   -0.042833
# 001101                       -1.218575                   -0.177917
# 001201                       -0.212110                   -0.164032
#
#            pos__mz=70.01279; rt=14.95  pos__mz=71.04989; rt=28.98  \
# sample_id
# 000801                      -0.426143                    0.874628
# 000901                      -0.399337                    0.222104
# 001001                      -0.040922                    0.712561
# 001101                      -0.854149                    0.573233
# 001201                      -0.236919                   -0.518318
#
#            pos__mz=72.08143; rt=105.95  pos__mz=73.06558; rt=167.92  ...  \
# sample_id                                                            ...
# 000801                       -0.024283                    -0.323829  ...
# 000901                        0.622867                     0.074509  ...
# 001001                       -0.472975                     0.340552  ...
# 001101                        1.123468                    -0.605034  ...
# 001201                       -0.546866                    -0.033378  ...
#
#            neg__mz=654.18771; rt=67.03  neg__mz=656.15980; rt=203.71  \
# sample_id
# 000801                       -0.612901                      0.548035
# 000901                       -0.611275                     -0.346408
# 001001                       -0.616297                     -0.252389
# 001101                       -0.614683                     -0.314993
# 001201                       -0.617482                      0.237696
#
#            neg__mz=675.16625; rt=65.13  neg__mz=675.96943; rt=30.26  \
# sample_id
# 000801                       -0.531445                     0.263013
# 000901                       -0.537859                     0.144652
# 001001                       -0.526669                    -0.698503
# 001101                       -0.522737                     0.176757
# 001201                       -0.551528                    -0.015762
#
#            neg__mz=676.17060; rt=65.25  neg__mz=681.98642; rt=129.46  \
# sample_id
# 000801                       -0.411286                      1.103103
# 000901                       -0.403738                      0.710903
# 001001                       -0.414413                     -0.822419
# 001101                       -0.409151                     -0.111489
# 001201                       -0.420836                      0.832534
#
#            neg__mz=816.99797; rt=74.89  neg__mz=829.27415; rt=159.14  \
# sample_id
# 000801                        0.584336                     -0.174954
# 000901                        0.967452                      0.161495
# 001001                        0.927149                      0.304728
# 001101                       -0.564600                     -0.827388
# 001201                        1.956994                      0.932708
#
#            neg__mz=830.27806; rt=59.04  neg__mz=835.29163; rt=159.46
# sample_id
# 000801                       -0.621487                      0.475356
# 000901                       -0.060305                      0.606356
# 001001                        0.284632                      1.283011
# 001101                       -0.484267                     -0.778742
# 001201                        0.659003                      1.467999
#
# [5 rows x 3166 columns]

# %% [markdown]
# ## 3. PCA és explroatív adatstruktúra

# %%
from src.metabolomics_multivariate import fit_pca
from src.metabolomics_plotting import plot_pca_multipanel, plot_pca_scores

pca_out = fit_pca(X_pareto, n_components=5, standardize=False)
scores = pca_out["scores"]
var = pca_out["explained_variance_ratio"]
print("Magyarázott variancia (első 5 PC):", [round(float(v), 4) for v in var])

fig = plot_pca_multipanel(pca_out, meta, hue_col="class_label")
fig.savefig(Path(FIGURES_DIR) / "pca_multipanel_mtbls28.png", dpi=150, bbox_inches="tight")

fig2 = plot_pca_scores(
    scores, meta,
    pc_x="PC1", pc_y="PC2",
    hue_col="class_label",
    explained=var,
    title="PCA score (Pareto-skálázott log1p, MTBLS28)",
)
fig2.savefig(Path(FIGURES_DIR) / "pca_scores_mtbls28.png", dpi=150, bbox_inches="tight")
# Out:
# Magyarázott variancia (első 5 PC): [0.1116, 0.0665, 0.062, 0.0365, 0.0342]

# %% [markdown]
# ## 4. Exploratív feature selection és biomarkerjelölt-keresés
# ### 4.1 Univariáns elemzés, FDR, volcano plot

# %%
# MTBLS28: minden minta egy vizeletes profil; csoport = class_label
metab = meta

from src.metabolomics_univariate import differential_analysis
from src.metabolomics_plotting import plot_volcano, plot_volcano_categorized

diff = differential_analysis(
    X_log,
    metab["class_label"],
    group_a="Lung cancer",
    group_b="Control",
    include_cohen_d=True,
)
print(diff.head(15))
fig = plot_volcano(diff, alpha=0.05, fc_thresh=0.5)
fig.savefig(Path(FIGURES_DIR) / "volcano_lung_cancer_vs_control_mtbls28.png", dpi=150, bbox_inches="tight")
figc = plot_volcano_categorized(
    diff,
    group_up="Lung cancer",
    group_down="Control",
    alpha=0.05,
    fc_thresh=0.5,
)
figc.savefig(Path(FIGURES_DIR) / "volcano_categorized_mtbls28.png", dpi=150, bbox_inches="tight")
# Out:
#                          feature  mean_Lung cancer  mean_Control    log2fc  \
# 0    pos__mz=264.12152; rt=23.31          5.356432      4.576635  0.226985
# 1    neg__mz=308.09849; rt=18.93          5.843039      5.500399  0.087183
# 2    pos__mz=372.92326; rt=27.98          5.550502      6.043579 -0.122785
# 3    pos__mz=615.03532; rt=34.29          4.897979      5.631643 -0.201369
# 4    pos__mz=423.00849; rt=33.92          6.392827      7.016368 -0.134270
# 5    pos__mz=252.97452; rt=32.25          6.926113      7.429240 -0.101169
# 6   pos__mz=340.11926; rt=319.58          5.129134      5.558804 -0.116059
# 7    pos__mz=215.01722; rt=32.24          9.895917     10.427071 -0.075429
# 8   neg__mz=239.09189; rt=336.89          5.863775      6.472963 -0.142597
# 9     pos__mz=407.03447; rt=3.72          5.690939      6.247701 -0.134659
# 10   pos__mz=424.01276; rt=34.37          4.709354      5.155416 -0.130560
# 11   pos__mz=429.02268; rt=33.90          5.051491      5.578264 -0.143107
# 12   pos__mz=444.99142; rt=33.79          4.988044      5.461875 -0.130922
# 13   pos__mz=215.16999; rt=32.13          6.398722      6.962593 -0.121841
# 14   pos__mz=542.95869; rt=34.39          4.506426      5.057418 -0.166417
#
#           pvalue  cohens_d          padj
# 0   9.666301e-52  1.039285  3.060351e-48
# 1   3.880187e-21  0.613142  6.142335e-18
# 2   1.366674e-20 -0.612615  1.442297e-17
# 3   6.451155e-19 -0.580405  5.106089e-16
# 4   1.015292e-17 -0.563956  6.176820e-15
# 5   1.259973e-17 -0.560440  6.176820e-15
# 6   1.365690e-17 -0.558280  6.176820e-15
# 7   1.663833e-17 -0.562061  6.584620e-15
# 8   2.141321e-17 -0.548486  7.532691e-15
# 9   4.380685e-17 -0.548466  1.386925e-14
# 10  5.712778e-17 -0.545833  1.644242e-14
# 11  2.351404e-16 -0.532962  6.203788e-14
# 12  4.806240e-16 -0.528888  1.170504e-13
# 13  6.447840e-16 -0.534485  1.458133e-13
# 14  7.281959e-16 -0.523108  1.495060e-13

# %% [markdown]
# ### 4.2 Top feature heatmap

# %%
from src.metabolomics_plotting import plot_top_features_heatmap

top_n = 25
top_feats = diff.nsmallest(top_n, "padj")["feature"].tolist()
fig = plot_top_features_heatmap(
    X_pareto,
    top_feats,
    metab,
    group_col="class_label",
    max_samples=50,
)
fig.savefig(Path(FIGURES_DIR) / "heatmap_top_features_mtbls28.png", dpi=150, bbox_inches="tight")

# %% [markdown]
# ### 4.3 PLS-DA, VIP és S-plot

# %%
from src.metabolomics_multivariate import fit_plsda_multiclass
from src.metabolomics_plotting import plot_s_plot_lv1
import matplotlib.pyplot as plt

plsda = fit_plsda_multiclass(
    X_pareto,
    metab["class_label"],
    n_components=3,
    scale=True,
)
s_pls = plsda["scores"]
vip = plsda["vip"]
print(vip.nlargest(10))

fig, ax = plt.subplots(figsize=(7, 5))
for lab in metab["class_label"].dropna().unique():
    m = metab["class_label"] == lab
    ax.scatter(s_pls.loc[m, "LV1"], s_pls.loc[m, "LV2"], label=str(lab), s=45, alpha=0.85, edgecolors="white", linewidths=0.3)
ax.set_xlabel("LV1")
ax.set_ylabel("LV2")
ax.set_title("PLS-DA score (MTBLS28: class_label)")
ax.legend(title="class_label")
ax.axhline(0, color="gray", lw=0.4)
ax.axvline(0, color="gray", lw=0.4)
fig.tight_layout()
fig.savefig(Path(FIGURES_DIR) / "plsda_scores_mtbls28.png", dpi=150, bbox_inches="tight")

w1 = plsda["model"].pls.x_weights_[:, 0]
figs = plot_s_plot_lv1(X_pareto, metab["class_label"], "Lung cancer", w1)
figs.savefig(Path(FIGURES_DIR) / "splot_lv1_mtbls28.png", dpi=150, bbox_inches="tight")
# Out:
# pos__mz=264.12152; rt=23.31     4.300867
# neg__mz=308.09849; rt=18.93     3.243606
# pos__mz=332.09634; rt=23.39     2.882242
# pos__mz=243.10048; rt=3.75      2.807744
# neg__mz=126.90693; rt=8.64      2.739464
# pos__mz=247.09705; rt=23.66     2.691072
# neg__mz=613.35956; rt=337.91    2.536442
# neg__mz=213.08713; rt=98.69     2.505154
# neg__mz=290.08851; rt=19.40     2.470099
# pos__mz=370.05260; rt=21.63     2.437504
# Name: VIP, dtype: float64

# %% [markdown]
# ### 4.4 Random Forest feature importance

# %%
from src.metabolomics_ml import (
    random_forest_feature_importance,
    plot_random_forest_feature_importance,
)

imp = random_forest_feature_importance(
    X_pareto,
    metab["class_label"],
    "Lung cancer",
    n_estimators=300,
)
print(imp.head(20))

plot_random_forest_feature_importance(
    imp,
    top_n=25,
    output_path=Path(FIGURES_DIR) / "rf_feature_importance_mtbls28.png",
)
# Out:
# pos__mz=264.12152; rt=23.31     0.014014
# pos__mz=486.25713; rt=125.04    0.005276
# neg__mz=308.09849; rt=18.93     0.005106
# neg__mz=441.16137; rt=307.95    0.003726
# pos__mz=340.11926; rt=319.58    0.003635
# pos__mz=656.20175; rt=3.99      0.003346
# neg__mz=208.06462; rt=94.76     0.003195
# pos__mz=584.26707; rt=131.43    0.002929
# neg__mz=122.02489; rt=22.88     0.002905
# pos__mz=204.13455; rt=48.37     0.002840
# neg__mz=613.35956; rt=337.91    0.002806
# pos__mz=274.09314; rt=132.72    0.002789
# pos__mz=561.34320; rt=328.95    0.002784
# pos__mz=478.17208; rt=1.24      0.002484
# neg__mz=126.90693; rt=8.64      0.002376
# pos__mz=243.10048; rt=3.75      0.002375
# pos__mz=296.12766; rt=309.45    0.002338
# neg__mz=239.09189; rt=336.89    0.002287
# pos__mz=638.36088; rt=328.13    0.002279
# pos__mz=252.97452; rt=32.25     0.002274
# Name: importance, dtype: float64
# (<Figure size 800x800 with 1 Axes>,
#  <Axes: title={'center': 'Random Forest feature importance (top 25)'}, xlabel='Importance', ylabel='Feature'>)

# %% [markdown]
# ## 5. Validált ML pipeline-ok: preprocessing, feature selection és modell-összehasonlítás
# ### 5.1 Cél és bemenet
# Cél: **Lung cancer vs Control** klasszifikáció validált, leakage-mentes pipeline-okkal.
#
# Bemenet: `X_raw`, `y = meta["class_label"]`.
# Pozitív osztály: `Lung cancer`, negatív osztály: `Control`.
#
# A validált ML rész elsődlegesen **nem** az előre számolt `X_pareto`-ból indul, hanem közvetlenül `X_raw`-ból.

# %% [markdown]
# ### 5.2 Train / validation / test split
# - 70% train
# - 15% validation
# - 15% test

# %%
import pandas as pd

from src.metabolomics_ml import make_train_valid_test_split

X_train, X_valid, X_test, y_train, y_valid, y_test = make_train_valid_test_split(
    X_raw,
    metab["class_label"],
    positive_label="Lung cancer",
    test_size=0.15,
    valid_size=0.15,
)

split_info = {
    "n_total": len(X_raw),
    "n_train": len(X_train),
    "n_valid": len(X_valid),
    "n_test": len(X_test),
}

split_info_df = pd.DataFrame(
    {
        "subset": ["train", "validation", "test"],
        "n_samples": [split_info["n_train"], split_info["n_valid"], split_info["n_test"]],
        "ratio": [
            split_info["n_train"] / split_info["n_total"],
            split_info["n_valid"] / split_info["n_total"],
            split_info["n_test"] / split_info["n_total"],
        ],
    }
)
split_info_df.to_csv(Path(REPORTS_DIR) / "split_info_mtbls28.csv", index=False)
split_info_df
# Out:
#        subset  n_samples     ratio
# 0       train        703  0.699502
# 1  validation        151  0.150249
# 2        test        151  0.150249

# %% [markdown]
# ### 5.3 Leakage-mentes preprocessing (pipeline-on belül)
# - missing value imputáció (median)
# - mintánkénti normalizálás
# - `log1p` transzformáció
# - alacsony varianciájú feature-ök kiszűrése
# - skálázás
#
# `fit`: csak train adaton, `transform`: validation/test adaton.
#
# ### 5.4 Pipeline-on belüli feature selection
# - `SelectKBest(f_classif)` több `k` értékkel
# - opcionálisan L1-logisztikus regresszió alapú szelekció
#
# ### 5.5 Modellek
# - Lasso (L1 logistic regression)
# - Ridge (L2 logistic regression)
# - Random Forest
# - XGBoost (ha elérhető)
# - Neural Network (TensorFlow MLP)

# %%
from src.metabolomics_ml import build_models

k_values = (50, 100, 200, 500)
selector_method = "kbest"
sample_normalization = "median"
scaler = "standard"
variance_threshold = 0.0

model_pool = build_models()
print("Modellek:", sorted(model_pool.keys()))
# Out:
# Modellek: ['lasso', 'mlp', 'random_forest', 'ridge', 'xgboost']

# %% [markdown]
# ### 5.6 Modellek tanítása, validáció és végső test értékelés
# Lépések:
# 1. minden modell × `k` kombináció futtatása train adaton,
# 2. validációs ROC-AUC alapján legjobb konfiguráció választása modellenként,
# 3. legjobb konfiguráció újratanítása train+valid adaton,
# 4. egyszeri final értékelés test adaton.

# %%
from copy import deepcopy
from pathlib import Path

import numpy as np
import pandas as pd

from src.metabolomics_ml import (
    build_model_pipeline,
    build_preprocess_pipeline,
    build_feature_selector,
    evaluate_binary_classifier,
    extract_model_features
)

ML_REPORTS_DIR = Path(REPORTS_DIR) / "ml_benchmark"
ML_FIGURES_DIR = Path(FIGURES_DIR) / "ml_benchmark"
(ML_FIGURES_DIR / "confusion_matrices").mkdir(parents=True, exist_ok=True)
(ML_FIGURES_DIR / "top_features").mkdir(parents=True, exist_ok=True)
ML_REPORTS_DIR.mkdir(parents=True, exist_ok=True)

metrics_rows = []
pred_frames = []
selected_frames = []
best_estimators = {}

for model_name, base_model in model_pool.items():
    print(f"\n[MODEL] {model_name}")
    best_auc = -np.inf
    best_k = None
    best_valid_metrics = None
    best_valid_preds = None

    for k in k_values:
        k_eff = int(min(k, X_train.shape[1]))
        if k_eff <= 0:
            continue

        preprocess = build_preprocess_pipeline(
            sample_normalization=sample_normalization,
            scaler=scaler,
            variance_threshold=variance_threshold,
        )
        selector = build_feature_selector(method=selector_method, k=k_eff)
        pipe = build_model_pipeline(preprocess, selector, deepcopy(base_model))
        pipe.fit(X_train, y_train)

        val_metrics, val_preds = evaluate_binary_classifier(
            pipe,
            X_valid,
            y_valid,
            dataset_name="validation",
            model_name=model_name,
        )
        val_metrics["k"] = k_eff
        print(f"  k={k_eff:>4} | val_roc_auc={val_metrics['roc_auc']:.4f}")
        if val_metrics["roc_auc"] > best_auc:
            best_auc = val_metrics["roc_auc"]
            best_k = k_eff
            best_valid_metrics = val_metrics
            best_valid_preds = val_preds

    if best_k is None or best_valid_metrics is None or best_valid_preds is None:
        print("  -> nincs érvényes konfiguráció")
        continue

    print(f"  -> best_k={best_k}, best_val_roc_auc={best_auc:.4f}")

    preprocess = build_preprocess_pipeline(
        sample_normalization=sample_normalization,
        scaler=scaler,
        variance_threshold=variance_threshold,
    )
    selector = build_feature_selector(method=selector_method, k=best_k)
    best_pipe = build_model_pipeline(preprocess, selector, deepcopy(base_model))

    X_train_valid = pd.concat([X_train, X_valid], axis=0)
    y_train_valid = pd.concat([y_train, y_valid], axis=0)
    best_pipe.fit(X_train_valid, y_train_valid)

    # Refit után csak test értékelés: a validation metrika a kiválasztási körből marad.
    test_metrics, test_preds = evaluate_binary_classifier(
        best_pipe, X_test, y_test, dataset_name="test", model_name=model_name
    )
    test_metrics["k"] = best_k
    print(f"  -> test_roc_auc={test_metrics['roc_auc']:.4f}")

    metrics_rows.extend([best_valid_metrics, test_metrics])
    pred_frames.extend([best_valid_preds, test_preds])
    best_estimators[model_name] = best_pipe

    feat_df = extract_model_features(
        best_pipe,
        original_feature_names=list(X_raw.columns),
        model_name=model_name,
        top_n=30,
    )
    feat_df["k"] = best_k
    selected_frames.append(feat_df)

metrics = pd.DataFrame(metrics_rows).sort_values(["model", "dataset"]).reset_index(drop=True)
predictions = pd.concat(pred_frames, ignore_index=True)
selected_features = pd.concat(selected_frames, ignore_index=True)

metrics.to_csv(ML_REPORTS_DIR / "ml_metrics.csv", index=False)
predictions.to_csv(ML_REPORTS_DIR / "ml_predictions.csv", index=False)
selected_features.to_csv(ML_REPORTS_DIR / "ml_selected_features.csv", index=False)
# Out:
# [MODEL] lasso
#   k=  50 | val_roc_auc=0.8710
#   k= 100 | val_roc_auc=0.8375
#   k= 200 | val_roc_auc=0.8572
#   k= 500 | val_roc_auc=0.8798
#   -> best_k=500, best_val_roc_auc=0.8798
#   -> test_roc_auc=0.8621
#
# [MODEL] ridge
#   k=  50 | val_roc_auc=0.8681
#   k= 100 | val_roc_auc=0.8287
#   k= 200 | val_roc_auc=0.8437
#   k= 500 | val_roc_auc=0.8769
#   -> best_k=500, best_val_roc_auc=0.8769
#   -> test_roc_auc=0.8563
#
# [MODEL] random_forest
#   k=  50 | val_roc_auc=0.8791
#   k= 100 | val_roc_auc=0.8569
#   k= 200 | val_roc_auc=0.8580
#   k= 500 | val_roc_auc=0.8585
#   -> best_k=50, best_val_roc_auc=0.8791
#   -> test_roc_auc=0.8737
#
# [MODEL] mlp
#   k=  50 | val_roc_auc=0.8592
#   k= 100 | val_roc_auc=0.8627
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d5aa68b8040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d5aa68b8040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   k= 200 | val_roc_auc=0.8884
#   k= 500 | val_roc_auc=0.8715
#   -> best_k=200, best_val_roc_auc=0.8884
#   -> test_roc_auc=0.8725
#
# [MODEL] xgboost
#   k=  50 | val_roc_auc=0.8614
#   k= 100 | val_roc_auc=0.8750
#   k= 200 | val_roc_auc=0.8775
#   k= 500 | val_roc_auc=0.8762
#   -> best_k=200, best_val_roc_auc=0.8775
#   -> test_roc_auc=0.8854

# %% [markdown]
# ### 5.7 ROC-görbék és confusion matrixok
# Publikációs jellegű összehasonlító ábrák mentése minden modellre.

# %%
from src.metabolomics_ml import (
    plot_metric_comparison,
    plot_roc_curves,
    plot_confusion_matrices
)

plot_metric_comparison(metrics, metric="roc_auc", output_path=ML_FIGURES_DIR / "metric_comparison_roc_auc.png")
plot_metric_comparison(metrics, metric="f1", output_path=ML_FIGURES_DIR / "metric_comparison_f1.png")
plot_roc_curves(predictions, output_path=ML_FIGURES_DIR / "roc_curves_test.png")
plot_confusion_matrices(metrics, output_dir=ML_FIGURES_DIR / "confusion_matrices")
# Out:
# /content/MetabolKD/src/metabolomics_ml.py:597: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# (<Figure size 1000x1900 with 11 Axes>,
#  array([[<Axes: title={'center': 'lasso (validation)'}, xlabel='Predicted', ylabel='True'>,
#          <Axes: title={'center': 'lasso (test)'}, xlabel='Predicted', ylabel='True'>],
#         [<Axes: title={'center': 'mlp (validation)'}, xlabel='Predicted', ylabel='True'>,
#          <Axes: title={'center': 'mlp (test)'}, xlabel='Predicted', ylabel='True'>],
#         [<Axes: title={'center': 'random_forest (validation)'}, xlabel='Predicted', ylabel='True'>,
#          <Axes: title={'center': 'random_forest (test)'}, xlabel='Predicted', ylabel='True'>],
#         [<Axes: title={'center': 'ridge (validation)'}, xlabel='Predicted', ylabel='True'>,
#          <Axes: title={'center': 'ridge (test)'}, xlabel='Predicted', ylabel='True'>],
#         [<Axes: title={'center': 'xgboost (validation)'}, xlabel='Predicted', ylabel='True'>,
#          <Axes: title={'center': 'xgboost (test)'}, xlabel='Predicted', ylabel='True'>]],
#        dtype=object))

# %% [markdown]
# ### 5.8 ML-alapú top feature-ök
# A `feature_summary` tábla kombinálja az univariáns, PLS-DA VIP, exploratív RF és validált ML feature-információkat.
#
# - `univariate_rank`
# - `plsda_vip_rank`
# - `rf_expl_rank`
# - `lasso_selected`
# - `rf_ml_importance`
# - `xgboost_importance`

# %%
from src.metabolomics_ml import plot_top_features

plot_top_features(
    selected_features,
    top_n=20,
    output_path=ML_FIGURES_DIR / "top_features_across_models.png",
)

metrics

# Integrált feature tábla az exploratív és validált eredményekből
univar_rank = diff[["feature", "padj"]].copy().sort_values("padj").reset_index(drop=True)
univar_rank["univariate_rank"] = np.arange(1, len(univar_rank) + 1)
univar_rank = univar_rank[["feature", "univariate_rank"]]

vip_rank = vip.sort_values(ascending=False).rename("vip").reset_index()
vip_rank.columns = ["feature", "vip"]
vip_rank["plsda_vip_rank"] = np.arange(1, len(vip_rank) + 1)
vip_rank = vip_rank[["feature", "plsda_vip_rank"]]

rf_expl_rank = imp.sort_values(ascending=False).rename("rf_expl_importance").reset_index()
rf_expl_rank.columns = ["feature", "rf_expl_importance"]
rf_expl_rank["rf_expl_rank"] = np.arange(1, len(rf_expl_rank) + 1)
rf_expl_rank = rf_expl_rank[["feature", "rf_expl_rank"]]

sel = selected_features.copy()
sel["lasso_selected"] = np.where(sel["model"] == "lasso", 1, 0)
sel_lasso = sel.groupby("feature", as_index=False)["lasso_selected"].max()

rf_ml = sel[sel["model"] == "random_forest"][["feature", "importance"]].rename(
    columns={"importance": "rf_ml_importance"}
)
xgb_ml = sel[sel["model"] == "xgboost"][["feature", "importance"]].rename(
    columns={"importance": "xgboost_importance"}
)

feature_summary = (
    univar_rank
    .merge(vip_rank, on="feature", how="outer")
    .merge(rf_expl_rank, on="feature", how="outer")
    .merge(sel_lasso, on="feature", how="left")
    .merge(rf_ml, on="feature", how="left")
    .merge(xgb_ml, on="feature", how="left")
)
feature_summary["lasso_selected"] = feature_summary["lasso_selected"].fillna(0).astype(int)

feature_summary = feature_summary.sort_values(
    ["univariate_rank", "plsda_vip_rank", "rf_expl_rank"],
    na_position="last",
).reset_index(drop=True)

feature_summary.to_csv(ML_REPORTS_DIR / "feature_summary_mtbls28.csv", index=False)
feature_summary.head(30)
# Out:
#                          feature  univariate_rank  plsda_vip_rank  \
# 0    pos__mz=264.12152; rt=23.31                1               1
# 1    neg__mz=308.09849; rt=18.93                2               2
# 2    pos__mz=372.92326; rt=27.98                3              40
# 3    pos__mz=615.03532; rt=34.29                4              44
# 4    pos__mz=423.00849; rt=33.92                5              68
# 5    pos__mz=252.97452; rt=32.25                6              82
# 6   pos__mz=340.11926; rt=319.58                7              60
# 7    pos__mz=215.01722; rt=32.24                8              80
# 8   neg__mz=239.09189; rt=336.89                9              79
# 9     pos__mz=407.03447; rt=3.72               10              90
# 10   pos__mz=424.01276; rt=34.37               11              78
# 11   pos__mz=429.02268; rt=33.90               12             105
# 12   pos__mz=444.99142; rt=33.79               13             106
# 13   pos__mz=215.16999; rt=32.13               14             103
# 14   pos__mz=542.95869; rt=34.39               15             116
# 15  neg__mz=232.03702; rt=302.96               16              43
# 16   pos__mz=415.96460; rt=34.51               17             110
# 17   pos__mz=520.97905; rt=34.16               18             121
# 18  neg__mz=474.14989; rt=291.13               19              46
# 19   pos__mz=247.09705; rt=23.66               20               6
# 20   pos__mz=236.99962; rt=33.17               21             109
# 21   pos__mz=437.97295; rt=34.02               22             114
# 22  neg__mz=229.14395; rt=335.27               23             124
# 23  neg__mz=244.08046; rt=247.72               24              88
# 24   neg__mz=421.00028; rt=27.82               25             130
# 25  pos__mz=227.05937; rt=265.09               26             144
# 26   pos__mz=409.02490; rt=34.83               27             140
# 27  neg__mz=141.09171; rt=286.81               28              83
# 28    neg__mz=311.97224; rt=7.18               29             126
# 29   pos__mz=451.00762; rt=33.65               30             147
#
#     rf_expl_rank  lasso_selected  rf_ml_importance  xgboost_importance
# 0              1               1          0.079508            0.038034
# 1              3               1          0.030521            0.007081
# 2             25               0               NaN                 NaN
# 3            108               0          0.016735            0.007959
# 4             21               0               NaN            0.007391
# 5             20               0          0.018010                 NaN
# 6              5               0               NaN                 NaN
# 7            117               0               NaN            0.008568
# 8             18               0               NaN                 NaN
# 9             38               0               NaN            0.007097
# 10            45               0               NaN            0.007112
# 11            78               0               NaN                 NaN
# 12            53               0               NaN                 NaN
# 13            90               0               NaN                 NaN
# 14            92               0               NaN                 NaN
# 15           152               0               NaN            0.007074
# 16            46               0               NaN                 NaN
# 17           226               0               NaN                 NaN
# 18            26               0               NaN                 NaN
# 19            34               0          0.030277                 NaN
# 20            97               0               NaN                 NaN
# 21            67               0               NaN                 NaN
# 22            29               0               NaN                 NaN
# 23            48               1               NaN                 NaN
# 24           208               0               NaN                 NaN
# 25            47               0               NaN                 NaN
# 26           265               0               NaN                 NaN
# 27            35               0               NaN                 NaN
# 28           207               0               NaN                 NaN
# 29            72               0               NaN                 NaN

# %%
from src.metabolomics_ml import summarize_top_features

summary_top = summarize_top_features(selected_features, top_n=20)

print(
    "Top feature összefoglaló (alapértelmezett rendezés: "
    "model_count csökkenő, mean_importance csökkenő, best_rank növekvő)."
)

# Opcionális alternatívák:
# summary_top = summarize_top_features(selected_features, top_n=20, sort_mode="importance")
# summary_top = summarize_top_features(selected_features, top_n=20, sort_mode="rank")

summary_top.to_csv(ML_REPORTS_DIR / "summary_top_features_mtbls28.csv", index=False)
summary_top.head(25)
# Out:
# Top feature összefoglaló (modellek közötti átfedés alapján):
#                          feature  model_count  mean_importance  best_rank
# 0    neg__mz=308.09849; rt=18.93            4        27.338201          2
# 1    pos__mz=264.12152; rt=23.31            3        67.081089          1
# 2   neg__mz=613.35956; rt=337.91            3        29.979067          4
# 3   pos__mz=561.34320; rt=328.95            3        24.799885          9
# 4   pos__mz=486.25713; rt=125.04            3        24.401146          8
# 5   neg__mz=441.16137; rt=307.95            3        24.065946          2
# 6   neg__mz=627.37617; rt=345.56            3        23.133603          5
# 7     neg__mz=126.90693; rt=8.64            3         0.881256          2
# 8     pos__mz=375.11532; rt=2.26            3         0.580979         10
# 9    pos__mz=247.09705; rt=23.66            2        46.555381          3
# 10  pos__mz=584.26707; rt=131.43            2        42.144343          5
# 11   pos__mz=332.09634; rt=23.39            2        38.805794          6
# 12  pos__mz=274.09314; rt=132.72            2        37.904331          7
# 13   pos__mz=247.13844; rt=26.81            2        34.487221         15
# 14   pos__mz=204.13455; rt=48.37            2        34.386933         15
# 15  neg__mz=628.37984; rt=345.75            2        33.826972          2
# 16   neg__mz=213.08713; rt=98.69            2        32.894906         10
# 17  pos__mz=170.06059; rt=284.49            2         1.850683          1
# 18   pos__mz=257.11419; rt=69.62            2         1.248531          2
# 19    neg__mz=127.05073; rt=3.24            2         1.181505          3
# 20   neg__mz=290.08851; rt=19.40            2         0.952414          6
# 21   pos__mz=282.14613; rt=76.32            2         0.939857          7
# 22  neg__mz=350.08713; rt=258.69            2         0.904796          5
# 23   neg__mz=396.11461; rt=19.18            2         0.892816          7
# 24   neg__mz=208.06462; rt=94.76            2         0.870439          6

# %% [markdown]
# ### 5.9 Overall top feature plot
# Az `overall` ábra a `summary_top` táblából készül, az aggregált (modellek közötti) fontossági információ alapján.

# %%
from src.metabolomics_ml import plot_top_features

overall_top = summary_top.copy().reset_index(drop=True)
overall_top["model"] = "overall"
overall_top["importance"] = overall_top["mean_importance"]
overall_top["rank"] = np.arange(1, len(overall_top) + 1)
overall_top["selection_method"] = "summary_consensus"

overall_plot_df = overall_top[["model", "feature", "importance", "rank", "selection_method"]]

plot_top_features(
    overall_plot_df,
    model_name="overall",
    top_n=20,
    output_path=ML_FIGURES_DIR / "top_features_overall_summary.png",
)

overall_top.head(25)

# %%
import shutil

# Notebook végén: teljes OUTPUT_DIR tükrözése Drive-ra
if str(GDRIVE_OUTPUT).startswith("/content/drive") and not Path("/content/drive").exists():
    print("[WARN] Google Drive nincs mountolva, másolás kihagyva.")
else:
    GDRIVE_OUTPUT.mkdir(parents=True, exist_ok=True)
    shutil.copytree(OUTPUT_DIR, GDRIVE_OUTPUT, dirs_exist_ok=True)
    print(f"OUTPUT_DIR másolva ide: {GDRIVE_OUTPUT}")
